# %%
# Data management imports
import pandas as pd
import numpy as np
import polars as pl
import polars.selectors as cs

# %%
nd = pl.read_parquet('../Data/insects.parquet')

# %%
ndp = nd.to_pandas()

# %%
ref_data_cols = np.unique(ndp.columns[np.random.randint(0,len(ndp.columns)-1, 100)])

# %%
rdc = [str(x) for x in ref_data_cols]

# %%
pl.from_pandas(ndp[ref_data_cols])
# Out:
# shape: (259_613, 98)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ domWoodTy ┆ hurs_mean ┆ hurs_mean ┆ hurs_mean ┆ … ┆ tasmin_su ┆ tasmin_su ┆ tasmin_su ┆ tasmin_s │
# │ pe_0      ┆ _30d_m11_ ┆ _30d_m3_p ┆ _30d_m4_p ┆   ┆ m_30d_m1_ ┆ m_30d_m2_ ┆ m_30d_m4_ ┆ um_30d_m │
# │ ---       ┆ pre1      ┆ re4       ┆ re1       ┆   ┆ pre3      ┆ year0     ┆ year0     ┆ 5_pre3   │
# │ i64       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1441      ┆ 87.812296 ┆ 76.055617 ┆ 73.762191 ┆ … ┆ -176.9187 ┆ 43.721785 ┆ 151.25154 ┆ 231.4207 │
# │           ┆           ┆           ┆           ┆   ┆ 36        ┆           ┆ 6         ┆ 77       │
# ...

# %%
pl.from_pandas(ndp)[rdc]
# Out:
# shape: (259_613, 98)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ domWoodTy ┆ hurs_mean ┆ hurs_mean ┆ hurs_mean ┆ … ┆ tasmin_su ┆ tasmin_su ┆ tasmin_su ┆ tasmin_s │
# │ pe_0      ┆ _30d_m11_ ┆ _30d_m3_p ┆ _30d_m4_p ┆   ┆ m_30d_m1_ ┆ m_30d_m2_ ┆ m_30d_m4_ ┆ um_30d_m │
# │ ---       ┆ pre1      ┆ re4       ┆ re1       ┆   ┆ pre3      ┆ year0     ┆ year0     ┆ 5_pre3   │
# │ i64       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1441      ┆ 87.812296 ┆ 76.055617 ┆ 73.762191 ┆ … ┆ -176.9187 ┆ 43.721785 ┆ 151.25154 ┆ 231.4207 │
# │           ┆           ┆           ┆           ┆   ┆ 36        ┆           ┆ 6         ┆ 77       │
# ...
